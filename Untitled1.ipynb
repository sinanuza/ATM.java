# %% [markdown]
# <a href="https://colab.research.google.com/github/sinanuza/ATM.java/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("audi.csv")

# %%
df.head(3)
# Out:
#    index    Year       Type  Mileage(miles)  ... MileageRank  PriceRank PPYRank Score
# 0      0  2018.0  Hatchback         44000.0  ...         215        163     340   718
# 1      4  2016.0  Hatchback         42596.0  ...         222        330     276   828
# 2      7  2015.0  Hatchback         42700.0  ...         221        327      94   642
#
# [3 rows x 16 columns]

# %%
df.drop(columns=["href","index","MileageRank","PriceRank","PPYRank","Score"])
# Out:
#        Year       Type  Mileage(miles) Engine  ...    Fuel Number_of_Owners Price(£)          PPY
# 0    2018.0  Hatchback         44000.0   1.6L  ...  Diesel                1  14995.0  2499.166667
# 1    2016.0  Hatchback         42596.0   1.0L  ...  Petrol                3  10755.0  2688.750000
# 2    2015.0  Hatchback         42700.0   1.4L  ...  Petrol                2  10799.0  3599.666667
# 3    2014.0  Hatchback         86000.0   1.6L  ...  Diesel                3   7490.0  3745.000000
# 4    2014.0  Hatchback        104310.0   1.6L  ...  Diesel                3   7400.0  3700.000000
# ..      ...        ...             ...    ...  ...     ...              ...      ...          ...
# 466  2014.0  Hatchback         40195.0   1.4L  ...  Petrol                3  11275.0  5637.500000
# 467  2020.0  Hatchback         26218.0   1.0L  ...  Petrol                1  18495.0  2311.875000
# 468  2017.0  Hatchback         48571.0   1.4L  ...  Petrol                2  11995.0  2399.000000
# ...

# %%
df=df.drop(columns=["href","index","MileageRank","PriceRank","PPYRank","Score"])

# %%
df.head(3)
# Out:
#      Year       Type  Mileage(miles) Engine  ...    Fuel Number_of_Owners Price(£)          PPY
# 0  2018.0  Hatchback         44000.0   1.6L  ...  Diesel                1  14995.0  2499.166667
# 1  2016.0  Hatchback         42596.0   1.0L  ...  Petrol                3  10755.0  2688.750000
# 2  2015.0  Hatchback         42700.0   1.4L  ...  Petrol                2  10799.0  3599.666667
#
# [3 rows x 10 columns]

# %%
#y=ax+b

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 471 entries, 0 to 470
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Year              471 non-null    float64
#  1   Type              471 non-null    object
#  2   Mileage(miles)    471 non-null    float64
#  3   Engine            471 non-null    object
#  4   PS                471 non-null    float64
#  5   Transmission      471 non-null    object
#  6   Fuel              471 non-null    object
#  7   Number_of_Owners  471 non-null    int64
#  8   Price(£)          471 non-null    float64
#  9   PPY               471 non-null    float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 36.9+ KB

# %%
df.head(3)
# Out:
#      Year       Type  Mileage(miles) Engine  ...    Fuel Number_of_Owners Price(£)          PPY
# 0  2018.0  Hatchback         44000.0   1.6L  ...  Diesel                1  14995.0  2499.166667
# 1  2016.0  Hatchback         42596.0   1.0L  ...  Petrol                3  10755.0  2688.750000
# 2  2015.0  Hatchback         42700.0   1.4L  ...  Petrol                2  10799.0  3599.666667
#
# [3 rows x 10 columns]

# %%
df.columns=["yil","kasa","mil","motor","ps","vites","yakit","sahip","fiyat","ppy"]

# %%
df.head(3)
# Out:
#       yil       kasa      mil motor          ps   vites   yakit  sahip    fiyat          ppy
# 0  2018.0  Hatchback  44000.0  1.6L  114.398422  Manual  Diesel      1  14995.0  2499.166667
# 1  2016.0  Hatchback  42596.0  1.0L   93.688363  Manual  Petrol      3  10755.0  2688.750000
# 2  2015.0  Hatchback  42700.0  1.4L  123.274162  Manual  Petrol      2  10799.0  3599.666667

# %%
df["motor"]=df["motor"].str.replace("L","")

# %%
df.head(3)
# Out:
#       yil       kasa      mil motor          ps   vites   yakit  sahip    fiyat          ppy
# 0  2018.0  Hatchback  44000.0   1.6  114.398422  Manual  Diesel      1  14995.0  2499.166667
# 1  2016.0  Hatchback  42596.0   1.0   93.688363  Manual  Petrol      3  10755.0  2688.750000
# 2  2015.0  Hatchback  42700.0   1.4  123.274162  Manual  Petrol      2  10799.0  3599.666667

# %%
df["motor"]=pd.to_numeric(df["motor"])

# %%
df.head(3)
# Out:
#       yil       kasa      mil  motor          ps   vites   yakit  sahip    fiyat          ppy
# 0  2018.0  Hatchback  44000.0    1.6  114.398422  Manual  Diesel      1  14995.0  2499.166667
# 1  2016.0  Hatchback  42596.0    1.0   93.688363  Manual  Petrol      3  10755.0  2688.750000
# 2  2015.0  Hatchback  42700.0    1.4  123.274162  Manual  Petrol      2  10799.0  3599.666667

# %%
pd.get_dummies(df,columns=['kasa','vites','yakit'])
# Out:
#         yil       mil  motor          ps  ...  vites_Automatic  vites_Manual  yakit_Diesel  yakit_Petrol
# 0    2018.0   44000.0    1.6  114.398422  ...            False          True          True         False
# 1    2016.0   42596.0    1.0   93.688363  ...            False          True         False          True
# 2    2015.0   42700.0    1.4  123.274162  ...            False          True         False          True
# 3    2014.0   86000.0    1.6  103.550296  ...            False          True          True         False
# 4    2014.0  104310.0    1.6  103.550296  ...            False          True          True         False
# ..      ...       ...    ...         ...  ...              ...           ...           ...           ...
# 466  2014.0   40195.0    1.4  138.067061  ...             True         False         False          True
# 467  2020.0   26218.0    1.0  114.398422  ...            False          True         False          True
# ...

# %%
df.head(3)
# Out:
#       yil       kasa      mil  motor          ps   vites   yakit  sahip    fiyat          ppy
# 0  2018.0  Hatchback  44000.0    1.6  114.398422  Manual  Diesel      1  14995.0  2499.166667
# 1  2016.0  Hatchback  42596.0    1.0   93.688363  Manual  Petrol      3  10755.0  2688.750000
# 2  2015.0  Hatchback  42700.0    1.4  123.274162  Manual  Petrol      2  10799.0  3599.666667

# %%
pd.get_dummies(df,columns=['vites','yakit'],drop_first=True)
# Out:
#         yil       mil  motor          ps  sahip    fiyat          ppy  vites_Manual  yakit_Petrol
# 0    2018.0   44000.0    1.6  114.398422      1  14995.0  2499.166667          True         False
# 1    2016.0   42596.0    1.0   93.688363      3  10755.0  2688.750000          True          True
# 2    2015.0   42700.0    1.4  123.274162      2  10799.0  3599.666667          True          True
# 3    2014.0   86000.0    1.6  103.550296      3   7490.0  3745.000000          True         False
# 4    2014.0  104310.0    1.6  103.550296      3   7400.0  3700.000000          True         False
# ..      ...       ...    ...         ...    ...      ...          ...           ...           ...
# 466  2014.0   40195.0    1.4  138.067061      3  11275.0  5637.500000         False          True
# 467  2020.0   26218.0    1.0  114.398422      1  18495.0  2311.875000          True          True
# 468  2017.0   48571.0    1.4  123.274162      2  11995.0  2399.000000          True          True
# ...

# %%
df[['vites_Manual','yakit_Petrol']]=df[['vites_Manual','yakit_Petrol']].astype(int)

# %%
print(df.columns)
# Out:
# Index(['yil', 'mil', 'motor', 'ps', 'vites', 'yakit', 'sahip', 'fiyat', 'ppy'], dtype='object')

# %%
df.head(3)
# Out:
#       yil      mil  motor          ps   vites   yakit  sahip    fiyat          ppy
# 0  2018.0  44000.0    1.6  114.398422  Manual  Diesel      1  14995.0  2499.166667
# 1  2016.0  42596.0    1.0   93.688363  Manual  Petrol      3  10755.0  2688.750000
# 2  2015.0  42700.0    1.4  123.274162  Manual  Petrol      2  10799.0  3599.666667

# %%
df = pd.get_dummies(df, columns=['vites', 'yakit'], prefix=['vites', 'yakit'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-141-9a454f7ac55b> in <cell line: 1>()
# ----> 1 df = pd.get_dummies(df, columns=['vites', 'yakit'], prefix=['vites', 'yakit'])
#       2
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/encoding.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     167             raise TypeError("Input must be a list-like for parameter `columns`")
#     168         else:
# --> 169             data_to_encode = data[columns]
#     170
#     171         # validate prefixes and separator to avoid silently dropping cols
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
# ...

# %%
df.head(3)
# Out:
#       yil      mil  motor          ps  sahip    fiyat  vites_Manual  yakit_Petrol
# 0  2018.0  44000.0    1.6  114.398422      1  14995.0             1             0
# 1  2016.0  42596.0    1.0   93.688363      3  10755.0             1             1
# 2  2015.0  42700.0    1.4  123.274162      2  10799.0             1             1

# %%
df[['vites_Manual', 'yakit_Petrol']] = df[['vites_Manual', 'yakit_Petrol']].astype(int)

# %%
df.head(3)
# Out:
#       yil      mil  motor          ps  sahip    fiyat  vites_Manual  yakit_Petrol
# 0  2018.0  44000.0    1.6  114.398422      1  14995.0             1             0
# 1  2016.0  42596.0    1.0   93.688363      3  10755.0             1             1
# 2  2015.0  42700.0    1.4  123.274162      2  10799.0             1             1

# %%
df.head(3)
# Out:
#       yil      mil  motor          ps  sahip    fiyat          ppy  vites_Manual  yakit_Petrol
# 0  2018.0  44000.0    1.6  114.398422      1  14995.0  2499.166667             1             0
# 1  2016.0  42596.0    1.0   93.688363      3  10755.0  2688.750000             1             1
# 2  2015.0  42700.0    1.4  123.274162      2  10799.0  3599.666667             1             1

# %%
df.head(100)
# Out:
#        yil       kasa       mil  motor  ...    fiyat          ppy  vites_Manual  yakit_Petrol
# 0   2018.0  Hatchback   44000.0    1.6  ...  14995.0  2499.166667             1             0
# 1   2016.0  Hatchback   42596.0    1.0  ...  10755.0  2688.750000             1             1
# 2   2015.0  Hatchback   42700.0    1.4  ...  10799.0  3599.666667             1             1
# 3   2014.0  Hatchback   86000.0    1.6  ...   7490.0  3745.000000             1             0
# 4   2014.0  Hatchback  104310.0    1.6  ...   7400.0  3700.000000             1             0
# ..     ...        ...       ...    ...  ...      ...          ...           ...           ...
# 95  2018.0  Hatchback   44600.0    1.4  ...  14000.0  2333.333333             1             1
# 96  2014.0  Hatchback   96182.0    1.6  ...   8495.0  4247.500000             1             0
# 97  2017.0  Hatchback   38000.0    1.4  ...  12699.0  2539.800000             1             1
# ...

# %%
df.head(3)
# Out:
#       yil       kasa      mil  motor  ...    fiyat          ppy  vites_Manual  yakit_Petrol
# 0  2018.0  Hatchback  44000.0    1.6  ...  14995.0  2499.166667             1             0
# 1  2016.0  Hatchback  42596.0    1.0  ...  10755.0  2688.750000             1             1
# 2  2015.0  Hatchback  42700.0    1.4  ...  10799.0  3599.666667             1             1
#
# [3 rows x 10 columns]

# %%
df = df.drop(columns=['kasa'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-145-be2cb7439b23> in <cell line: 1>()
# ----> 1 df = df.drop(columns=['kasa'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df.head(3)
# Out:
#       yil      mil  motor          ps  sahip    fiyat  vites_Manual  yakit_Petrol
# 0  2018.0  44000.0    1.6  114.398422      1  14995.0             1             0
# 1  2016.0  42596.0    1.0   93.688363      3  10755.0             1             1
# 2  2015.0  42700.0    1.4  123.274162      2  10799.0             1             1

# %%
y=df[["fiyat"]]
x=df.drop("fiyat",axis=1)

# %%
#lm=LinearRegression()
#model=lm.fit(x,y)

# %%
model.predict([[2017,30000,1.6,110,1,2600,0,1]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[13145.9080419]])

# %%
#model.score(x,y)
# Out:
# 0.9595295772839731

# %%
df.head(3)
# Out:
#       yil      mil  motor          ps  sahip    fiyat          ppy  vites_Manual  yakit_Petrol
# 0  2018.0  44000.0    1.6  114.398422      1  14995.0  2499.166667             1             0
# 1  2016.0  42596.0    1.0   93.688363      3  10755.0  2688.750000             1             1
# 2  2015.0  42700.0    1.4  123.274162      2  10799.0  3599.666667             1             1

# %%
x_train, x_test, y_train,y_test=train_test_split(x,y,train_size=22)

# %%
lm=LinearRegression()
model=lm.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.9142936834652063

# %%
df.head(3)
# Out:
#       yil      mil  motor          ps  sahip    fiyat          ppy  vites_Manual  yakit_Petrol
# 0  2018.0  44000.0    1.6  114.398422      1  14995.0  2499.166667             1             0
# 1  2016.0  42596.0    1.0   93.688363      3  10755.0  2688.750000             1             1
# 2  2015.0  42700.0    1.4  123.274162      2  10799.0  3599.666667             1             1

# %%
df=df.drop(columns=["ppy"])

# %%
df.head(4)
# Out:
#       yil      mil  motor          ps  sahip    fiyat  vites_Manual  yakit_Petrol
# 0  2018.0  44000.0    1.6  114.398422      1  14995.0             1             0
# 1  2016.0  42596.0    1.0   93.688363      3  10755.0             1             1
# 2  2015.0  42700.0    1.4  123.274162      2  10799.0             1             1
# 3  2014.0  86000.0    1.6  103.550296      3   7490.0             1             0

# %%
y=df[["fiyat"]]
x=df.drop("fiyat",axis=1)

# %%
model.predict([[2016,30000,1.0,90,5,0,1,1]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[4538.62335739]])
