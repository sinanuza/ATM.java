# %% [markdown]
# <a href="https://colab.research.google.com/github/sinanuza/ATM.java/blob/main/Pandas_Numpy_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.linear_model import LinearRegression
import pandas as pd

# %%
df=pd.read_csv('student.csv')

# %%
df.head(4)
# Out:
#    number_courses  time_study   Marks
# 0               3       4.508  19.202
# 1               4       0.096   7.734
# 2               4       3.133  13.811
# 3               6       7.909  53.018

# %%
df.columns=["sinif","saat","puan"]

# %%
df.head(4)
# Out:
#    sinif   saat    puan
# 0      3  4.508  19.202
# 1      4  0.096   7.734
# 2      4  3.133  13.811
# 3      6  7.909  53.018

# %%
y=df[["puan"]]
x=df[["sinif","saat"]]

# %%
lm=LinearRegression()
model=lm.fit(x,y)

# %%
# y=ax+b

# %%
model.coef_ #katsayi
# Out:
# array([[1.86405074, 5.39917879]])

# %%
model.intercept_ #sabit
# Out:
# array([-7.45634623])

# %%
model.predict([[4,5]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[26.99575068]])

# %%
(6*1.86405074)+(8*5.39917879)+(-7.45634623)
# Out:
# 46.921388529999994

# %%
model.predict([[6,8]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[46.92138853]])

# %%
df.head(3)
# Out:
#    sinif   saat    puan
# 0      3  4.508  19.202
# 1      4  0.096   7.734
# 2      4  3.133  13.811

# %%
s1=model.predict([[3,4.508]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
(19.202-s1)/19.202
# Out:
# array([[-0.17046682]])

# %%
df.head(8)
# Out:
#    sinif   saat    puan
# 0      3  4.508  19.202
# 1      4  0.096   7.734
# 2      4  3.133  13.811
# 3      6  7.909  53.018
# 4      8  7.811  55.299
# 5      6  3.211  17.822
# 6      3  6.063  29.889
# 7      5  3.413  17.264
