# %% [markdown]
# <a href="https://colab.research.google.com/github/sinanuza/ATM.java/blob/main/randomforrest_regressor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://www.kaggle.com/datasets/mirichoi0218/insurance

import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('insurance.csv')

# %%
data.head(3)
# Out:
#    age    bmi  children  ...  region_northwest  region_southeast  region_southwest
# 0   19  27.90         0  ...             False             False              True
# 1   18  33.77         1  ...             False              True             False
# 2   28  33.00         3  ...             False              True             False
#
# [3 rows x 9 columns]

# %%
data=pd.get_dummies(data, columns=['sex', 'smoker', 'region'],drop_first=True)

# %%
data[['sex_male','smoker_yes','region_northwest','region_southeast','region_southwest']]=data[['sex_male','smoker_yes','region_northwest','region_southeast','region_southwest']].astype(int)

# %%
data.head(3)
# Out:
#    age    bmi  children  ...  region_northwest  region_southeast  region_southwest
# 0   19  27.90         0  ...                 0                 0                 1
# 1   18  33.77         1  ...                 0                 1                 0
# 2   28  33.00         3  ...                 0                 1                 0
#
# [3 rows x 9 columns]

# %%
y=data['charges']
x=data.drop('charges',axis=1)

# %%
x
# Out:
#       age     bmi  children  ...  region_northwest  region_southeast  region_southwest
# 0      19  27.900         0  ...                 0                 0                 1
# 1      18  33.770         1  ...                 0                 1                 0
# 2      28  33.000         3  ...                 0                 1                 0
# 3      33  22.705         0  ...                 1                 0                 0
# 4      32  28.880         0  ...                 1                 0                 0
# ...   ...     ...       ...  ...               ...               ...               ...
# 1333   50  30.970         3  ...                 1                 0                 0
# 1334   18  31.920         0  ...                 0                 0                 0
# 1335   18  36.850         0  ...                 0                 1                 0
# 1336   21  25.800         0  ...                 0                 0                 1
# ...

# %%
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=22,train_size=0.7)

# %%
lr=LinearRegression()
model=lr.fit(x_train,y_train)

# %%
model.score(x_test,y_test)
# Out:
# 0.7398405242767803

# %%
rf=RandomForestRegressor(n_estimators=200)
model=rf.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.827917198848316
